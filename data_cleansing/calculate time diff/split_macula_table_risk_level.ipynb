# %%
import pandas as pd

# %%
df = pd.read_excel("macula_table_risk_level.xlsx")

# %%
df
# Out:
#        label                           macula_filename      pid eye  \
# 0          1  STDR001_OD_20150728_105647_Color_001.tif  STDR001  OD
# 1          2  STDR001_OD_20160714_101437_Color_001.tif  STDR001  OD
# 2          2  STDR001_OD_20160714_101504_Color_001.tif  STDR001  OD
# 3          2  STDR001_OD_20160714_101606_Color_001.tif  STDR001  OD
# 4          2  STDR001_OD_20170117_110223_Color_001.tif  STDR001  OD
# ...      ...                                       ...      ...  ..
# 11364      0  STDR696_OD_20230613_145815_Color_001.tif  STDR696  OD
# 11365      0  STDR696_OS_20210629_160514_Color_001.tif  STDR696  OS
# 11366      0  STDR696_OS_20211216_152742_Color_001.tif  STDR696  OS
# 11367      1  STDR696_OS_20220614_160840_Color_001.tif  STDR696  OS
# 11368      1  STDR696_OS_20230613_145738_Color_001.tif  STDR696  OS
#
#             date      time  label_fix_inconsit  label_183  label_365  \
# 0     2015-07-28  10:56:47                   1        NaN        2.0
# ...

# %%
df_365 = df[["macula_filename", "label_365_diff_binary"]]

# %%
df_365
# Out:
#                                 macula_filename  label_365_diff_binary
# 0      STDR001_OD_20150728_105647_Color_001.tif                    1.0
# 1      STDR001_OD_20160714_101437_Color_001.tif                    NaN
# 2      STDR001_OD_20160714_101504_Color_001.tif                    NaN
# 3      STDR001_OD_20160714_101606_Color_001.tif                    NaN
# 4      STDR001_OD_20170117_110223_Color_001.tif                    NaN
# ...                                         ...                    ...
# 11364  STDR696_OD_20230613_145815_Color_001.tif                    NaN
# 11365  STDR696_OS_20210629_160514_Color_001.tif                    1.0
# 11366  STDR696_OS_20211216_152742_Color_001.tif                    NaN
# 11367  STDR696_OS_20220614_160840_Color_001.tif                    0.0
# 11368  STDR696_OS_20230613_145738_Color_001.tif                    NaN
#
# [11369 rows x 2 columns]

# %%
df_365.dropna(inplace=True)
# Out:
# /tmp/ipykernel_4046600/2779731032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_365.dropna(inplace=True)

# %%
df_365
# Out:
#                                 macula_filename  label_365_diff_binary
# 0      STDR001_OD_20150728_105647_Color_001.tif                    1.0
# 6      STDR001_OS_20150728_105826_Color_001.tif                    0.0
# 7      STDR001_OS_20150728_105927_Color_001.tif                    0.0
# 8      STDR001_OS_20150728_110128_Color_001.tif                    0.0
# 15     STDR002_OD_20160223_104317_Color_001.tif                    0.0
# ...                                         ...                    ...
# 11359  STDR695_OS_20220906_153920_Color_001.tif                    0.0
# 11361  STDR696_OD_20210629_160614_Color_001.tif                    0.0
# 11363  STDR696_OD_20220614_160758_Color_001.tif                    0.0
# 11365  STDR696_OS_20210629_160514_Color_001.tif                    1.0
# 11367  STDR696_OS_20220614_160840_Color_001.tif                    0.0
#
# [6228 rows x 2 columns]

# %%
df_365.to_excel("macula_table_risk_level_365.xlsx")

# %%
labels_count = df_365.label_365_diff_binary.value_counts()

# %%
labels_count / len(df_365)
# Out:
# label_365_diff_binary
# 0.0    0.942839
# 1.0    0.057161
# Name: count, dtype: float64
